# %%
import pandas as pd
import os

# %%
csv_file=pd.read_csv("C:/Java/hateful_speech/data.csv")

# %%
csv_file.head(20)
# Out:
#     Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0            0      3            0                   0        3      2
# 1            1      3            0                   3        0      1
# 2            2      3            0                   3        0      1
# 3            3      3            0                   2        1      1
# 4            4      6            0                   6        0      1
# 5            5      3            1                   2        0      1
# 6            6      3            0                   3        0      1
# 7            7      3            0                   3        0      1
# 8            8      3            0                   3        0      1
# 9            9      3            1                   2        0      1
# 10          10      3            0                   3        0      1
# 11          11      3            0                   3        0      1
# ...
